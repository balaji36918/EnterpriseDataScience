# %%
import subprocess
import os
import pandas as pd
import numpy as np

from datetime import datetime


# %matplotlib inline
pd.set_option('display.max_rows', 500)

# %%
git_pull = subprocess.Popen( "/usr/bin/git pull" , 
                     cwd = os.path.dirname( '../data/raw/COVID-19/' ), 
                     shell = True, 
                     stdout = subprocess.PIPE, 
                     stderr = subprocess.PIPE )
(out, error) = git_pull.communicate()

# %%
data_path='/home/balaji/dsProject/data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  6/14/22  6/15/22  6/16/22  \
# 0        0        0        0        0  ...   181178   181236   181465
# 1        0        0        0        0  ...   276821   276821   276821
# 2        0        0        0        0  ...   265943   265952   265964
# 3        0        0        0        0  ...    43224    43449    43449
# 4        0        0        0        0  ...    99761    99761    99761
#
#    6/17/22  6/18/22  6/19/22  6/20/22  6/21/22  6/22/22  6/23/22
# ...

# %%
time_idx = pd_raw.columns[4:]

# %%
df_plot = pd.DataFrame({'date':time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                            Antarctica
# 6                   Antigua and Barbuda
# 7                             Argentina
# 8                               Armenia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                            Australia
# 17                              Austria
# 18                           Azerbaijan
# 19                              Bahamas
# 20                              Bahrain
# 21                           Bangladesh
# 22                             Barbados
# ...

# %%
pd_raw[pd_raw['Country/Region']== 'Germany'].iloc[:, 4::].sum(axis=0)[0:4]
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# dtype: int64

# %%
country_list = ['US', 'Germany', 'India']

# %%
for each in country_list:
    df_plot[each]=np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
# %matplotlib inline
df_plot.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Data Type Date:

# %%
df_plot.head()
# Out:
#       date  US  Germany  India
# 0  1/22/20   1        0      0
# 1  1/23/20   1        0      0
# 2  1/24/20   2        0      0
# 3  1/25/20   2        0      0
# 4  1/26/20   5        0      0

# %%
time_idx=[datetime.strptime( each,"%m/%d/%y") for each in df_plot.date] # convert to datetime
time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # convert back to date ISO norm (str)

# %%
df_plot['date']=time_idx
type(df_plot['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
type(df['population'])
# Out:
# pandas.core.series.Series

# %%
df_plot['population_data'] = df['population'].copy()
df_plot['population_data'] = df_plot['population_data'].fillna(df['population'])

# %%
df_plot.tail()
# Out:
#           date        US   Germany     India  population_data
# 879 2022-06-19  86246101  27211896  43309473     1.373486e+09
# 880 2022-06-20  86297081  27334993  43319396     1.373486e+09
# 881 2022-06-21  86452232  27454225  43331645     1.373486e+09
# 882 2022-06-22  86636306  27573585  43344958     1.373486e+09
# 883 2022-06-23  86757621  27681775  43362294     1.373486e+09

# %%
df_plot.to_csv('/home/balaji/dsProject/data/processed/COVID_small_flat_table.csv', sep=';', index = False)

# %% [markdown]
# Relational data model - defining a primary key

# %%
pd_data_base=pd_raw.rename(columns={'Country/Region':'country',
                      'Province/State':'state'})
pd_data_base['state']=pd_data_base['state'].fillna('no')  #ensure a sring, important for indexing

# %%
pd_data_base=pd_data_base.drop(['Lat','Long'],axis=1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    no  Afghanistan        0        0        0        0        0        0
# 1    no      Albania        0        0        0        0        0        0
# 2    no      Algeria        0        0        0        0        0        0
# 3    no      Andorra        0        0        0        0        0        0
# 4    no       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  6/14/22  6/15/22  6/16/22  6/17/22  6/18/22  \
# 0        0        0  ...   181178   181236   181465   181534   181574
# 1        0        0  ...   276821   276821   276821   277141   277141
# 2        0        0  ...   265943   265952   265964   265968   265971
# 3        0        0  ...    43224    43449    43449    43449    43449
# 4        0        0  ...    99761    99761    99761    99761    99761
#
#    6/19/22  6/20/22  6/21/22  6/22/22  6/23/22
# ...

# %%
test_pd = pd_data_base.set_index(['state', 'country']).T

# %%
test_pd.columns
# Out:
# MultiIndex([(                          'no',          'Afghanistan'),
#             (                          'no',              'Albania'),
#             (                          'no',              'Algeria'),
#             (                          'no',              'Andorra'),
#             (                          'no',               'Angola'),
#             (                          'no',           'Antarctica'),
#             (                          'no',  'Antigua and Barbuda'),
#             (                          'no',            'Argentina'),
#             (                          'no',              'Armenia'),
#             ('Australian Capital Territory',            'Australia'),
#             ...
#             (                          'no',              'Uruguay'),
#             (                          'no',           'Uzbekistan'),
#             (                          'no',              'Vanuatu'),
# ...

# %%
test_pd.stack(level=[0,1]).reset_index()
# Out:
#         level_0                         state               country         0
# 0       1/22/20                       Alberta                Canada       0.0
# 1       1/22/20                      Anguilla        United Kingdom       0.0
# 2       1/22/20                         Anhui                 China       1.0
# 3       1/22/20                         Aruba           Netherlands       0.0
# 4       1/22/20  Australian Capital Territory             Australia       0.0
# ...         ...                           ...                   ...       ...
# 251935  6/23/22                            no    West Bank and Gaza  658503.0
# 251936  6/23/22                            no  Winter Olympics 2022     535.0
# 251937  6/23/22                            no                 Yemen   11824.0
# 251938  6/23/22                            no                Zambia  324922.0
# 251939  6/23/22                            no              Zimbabwe  255136.0
#
# [251940 rows x 4 columns]

# %%
pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model.head()
# Out:
#       date                         state         country  confirmed
# 0  1/22/20                       Alberta          Canada        0.0
# 1  1/22/20                      Anguilla  United Kingdom        0.0
# 2  1/22/20                         Anhui           China        1.0
# 3  1/22/20                         Aruba     Netherlands        0.0
# 4  1/22/20  Australian Capital Territory       Australia        0.0

# %%
pd_relational_model.dtypes
# Out:
# date          object
# state         object
# country       object
# confirmed    float64
# dtype: object

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed           float64
# dtype: object

# %%
pd_relational_model.confirmed=pd_relational_model.confirmed.astype(int)

pd_relational_model.to_csv('/home/balaji/dsProject/data/processed/COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model[pd_relational_model['country']=='US'].tail())
# Out:
#              date state country  confirmed
# 250785 2022-06-19    no      US   86246101
# 251070 2022-06-20    no      US   86297081
# 251355 2022-06-21    no      US   86452232
# 251640 2022-06-22    no      US   86636306
# 251925 2022-06-23    no      US   86757621
